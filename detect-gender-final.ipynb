# %%
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping 
import matplotlib as plt
from keras.preprocessing.image import ImageDataGenerator 

# Gọi các thư viện cần thiết
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler # Xử lý chuẩn hóa dữ liệu
from sklearn.model_selection import train_test_split # Chia dữ liệu ra làm 2 phần
from keras.layers import Dense, Activation, Dropout, BatchNormalization,LSTM # LSTM biên dạng ANN, BatchNormalization: cho nhỏ lại
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical # Sử dung để làm nổi đối tượng cần phân loại
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score # Để đo lường
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Preprocessing
train = ImageDataGenerator(rescale=1/255)
image_generator = ImageDataGenerator(rescale=1/255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=32,
                                                    directory="../input/data-gender-final/gender",
                                                    shuffle=True,
                                                    target_size=(150,150), 
                                                    subset="training",
                                                    class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=32,
                                                        directory="../input/data-gender-final/gender",
                                                        shuffle=True,
                                                        target_size=(150,150), 
                                                        subset="validation",
                                                        class_mode='categorical')
# Out:
# Found 3966 images belonging to 4 classes.
# Found 989 images belonging to 4 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'female': 0, 'female_mask': 1, 'male': 2, 'male_mask': 3}

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(16,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(16,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
# model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
# model.add(MaxPooling2D(2,2))
# model.add(Conv2D(256,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 256 lần tích chập
# model.add(Conv2D(256,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
# model.add(MaxPooling2D(2,2))

# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# 2022-06-22 13:19:47.006124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:47.087390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:47.088152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:47.089266: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-22 13:19:47.089568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 43808)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5607552
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 5,624,724
# Trainable params: 5,624,724
# Non-trainable params: 0
# _________________________________________________________________
# node zero
# 2022-06-22 13:19:47.090248: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:47.090896: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:49.211414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:49.212297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:49.212993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 13:19:49.213594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=32,epochs=100,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-06-22 13:19:54.692520: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-06-22 13:19:56.174318: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 124/124 [==============================] - 47s 323ms/step - loss: 0.7988 - accuracy: 0.6412 - val_loss: 0.6262 - val_accuracy: 0.7634
# Epoch 2/100
# 124/124 [==============================] - 14s 109ms/step - loss: 0.5241 - accuracy: 0.7779 - val_loss: 0.5684 - val_accuracy: 0.7604
# Epoch 3/100
# 124/124 [==============================] - 14s 113ms/step - loss: 0.4269 - accuracy: 0.8215 - val_loss: 0.4875 - val_accuracy: 0.7867
# Epoch 4/100
# 124/124 [==============================] - 13s 107ms/step - loss: 0
100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.8377 - val_accuracy: 0.8726
# Epoch 43/100
# 124/124 [==============================] - 14s 110ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.7956 - val_accuracy: 0.8756
# Epoch 44/100
# 124/124 [==============================] - 14s 112ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.7515 - val_accuracy: 0.8807
# Epoch 45/100
# 124/124 [==============================] - 13s 109ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.8881 - val_accuracy: 0.8645
# Epoch 46/100
# 124/124 [==============================] - 13s 109ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.7907 - val_accuracy: 0.8716
# Epoch 47/100
# 124/124 [==============================] - 15s 119ms/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.8477 - val_accuracy: 0.8716
# Epoch 48/100
# 124/124 [==============================] - 14s 113ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.8464 - val_accuracy: 0.8706
# Epoch 49/100
# 124/124 [==============================] - 15s 117ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.7442 - val_accuracy: 0.8807
# Epoch 50/100
# 124/124 [==============================] - 14s 117ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.7939 - val_accuracy: 0.8645
# Epoch 51/100
# 124/124 [==============================] - 14s 117ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.8329 - val_accuracy: 0.8746
# Epoch 52/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.8290 - val_accuracy: 0.8736
# Epoch 53/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.8194 - val_accuracy: 0.8787
# Epoch 54/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.8219 - val_accuracy: 0.8918
# Epoch 55/100
# 124/124 [==============================] - 14s 113ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.9433 - val_accuracy: 0.8514
# Epoch 56/100
# 124/124 [==============================] - 15s 121ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.6850 - val_accuracy: 0.8787
# Epoch 57/100
# 124/124 [==============================] - 14s 115ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.7810 - val_accuracy: 0.8756
# Epoch 58/100
# 124/124 [==============================] - 15s 118ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.7588 - val_accuracy: 0.8999
# Epoch 59/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.8034 - val_accuracy: 0.8837
# Epoch 60/100
# 124/124 [==============================] - 15s 118ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.8102 - val_accuracy: 0.8787
# Epoch 61/100
# 124/124 [==============================] - 14s 115ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.7301 - val_accuracy: 0.8837
# Epoch 62/100
# 124/124 [==============================] - 14s 116ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.8524 - val_accuracy: 0.8605
# Epoch 63/100
# 124/124 [==============================] - 14s 110ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.7798 - val_accuracy: 0.8827
# Epoch 64/100
# 124/124 [==============================] - 14s 110ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.8128 - val_accuracy: 0.8787
# Epoch 65/100
# 124/124 [==============================] - 14s 115ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.8147 - val_accuracy: 0.8817
# Epoch 66/100
# 124/124 [==============================] - 14s 109ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.7718 - val_accuracy: 0.8938
# Epoch 67/100
# 124/124 [==============================] - 14s 115ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.7872 - val_accuracy: 0.8888
# Epoch 68/100
# 124/124 [==============================] - 13s 109ms/step - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.8585 - val_accuracy: 0.8726
# Epoch 69/100
# 124/124 [==============================] - 14s 113ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.8566 - val_accuracy: 0.8888
# Epoch 70/100
# 124/124 [==============================] - 14s 116ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 0.7791 - val_accuracy: 0.8878
# Epoch 71/100
# 124/124 [==============================] - 14s 111ms/step - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.8552 - val_accuracy: 0.8696
# Epoch 72/100
# 124/124 [==============================] - 13s 107ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.9752 - val_accuracy: 0.8534
# Epoch 73/100
# 124/124 [==============================] - 13s 107ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 0.8008 - val_accuracy: 0.8766
# Epoch 74/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.8395 - val_accuracy: 0.8716
# Epoch 75/100
# 124/124 [==============================] - 14s 110ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.7507 - val_accuracy: 0.8847
# Epoch 76/100
# 124/124 [==============================] - 14s 111ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 1.1188 - val_accuracy: 0.8372
# Epoch 77/100
# 124/124 [==============================] - 13s 107ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.9039 - val_accuracy: 0.8564
# Epoch 78/100
# 124/124 [==============================] - 13s 109ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.8130 - val_accuracy: 0.8766
# Epoch 79/100
# 124/124 [==============================] - 14s 113ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.8498 - val_accuracy: 0.8756
# Epoch 80/100
# 124/124 [==============================] - 13s 108ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.7738 - val_accuracy: 0.8938
# Epoch 81/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.8179 - val_accuracy: 0.8787
# Epoch 82/100
# 124/124 [==============================] - 13s 107ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.9009 - val_accuracy: 0.8534
# Epoch 83/100
# 124/124 [==============================] - 14s 112ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.7547 - val_accuracy: 0.8928
# Epoch 84/100
# 124/124 [==============================] - 13s 108ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.8473 - val_accuracy: 0.8655
# Epoch 85/100
# 124/124 [==============================] - 13s 108ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 0.8274 - val_accuracy: 0.8787
# Epoch 86/100
# 124/124 [==============================] - 14s 112ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.8348 - val_accuracy: 0.8746
# Epoch 87/100
# 124/124 [==============================] - 14s 111ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.9602 - val_accuracy: 0.8473
# Epoch 88/100
# 124/124 [==============================] - 14s 112ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.7655 - val_accuracy: 0.8918
# Epoch 89/100
# 124/124 [==============================] - 14s 110ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.8356 - val_accuracy: 0.8716
# Epoch 90/100
# 124/124 [==============================] - 14s 109ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 0.9367 - val_accuracy: 0.8554
# Epoch 91/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.8291 - val_accuracy: 0.8787
# Epoch 92/100
# 124/124 [==============================] - 13s 108ms/step - loss: 8.9446e-04 - accuracy: 0.9995 - val_loss: 0.8120 - val_accuracy: 0.8787
# Epoch 93/100
# 124/124 [==============================] - 14s 112ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.7710 - val_accuracy: 0.8959
# Epoch 94/100
# 124/124 [==============================] - 13s 108ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.8809 - val_accuracy: 0.8625
# Epoch 95/100
# 124/124 [==============================] - 13s 108ms/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.9283 - val_accuracy: 0.8473
# Epoch 96/100
# 124/124 [==============================] - 14s 111ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.8105 - val_accuracy: 0.8756
# Epoch 97/100
# 124/124 [==============================] - 13s 108ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 1.0018 - val_accuracy: 0.8443
# Epoch 98/100
# 124/124 [==============================] - 14s 115ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.7532 - val_accuracy: 0.8908
# Epoch 99/100
# 124/124 [==============================] - 14s 111ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 0.7926 - val_accuracy: 0.8817
# Epoch 100/100
# 124/124 [==============================] - 14s 114ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.9456 - val_accuracy: 0.8524

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  0.945558488368988
# Độ chính xác  0.8523761630058289

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/data-fm-id-gd/Detect_faceMask_gender_indentified/dhung_nomask/dhung_nomask (259).jpg"


img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("female")
if(kq==1):
    print("female")
if(kq==2 ):
    print("male")
if(kq==3 ):
    print("male")
# Out:
# male

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/test-maskgender/file_test/z3452937837215_afb2803bec16153d47657fc5d3d9d362.jpg"


img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("female")
if(kq==1):
    print("female")
if(kq==2 ):
    print("male")
if(kq==3 ):
    print("male")
# Out:
# female

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/test-maskgender/file_test/z3453394133999_1e6ad8d3e8d962a8055d9eae414e23be.jpg"


img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("female")
if(kq==1):
    print("female")
if(kq==2 ):
    print("male")
if(kq==3 ):
    print("male")
# Out:
# female

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/data-fm-id-gd/Detect_faceMask_gender_indentified/dhung_mask/119.jpg"


img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("female")
if(kq==1):
    print("female")
if(kq==2 ):
    print("male")
if(kq==3 ):
    print("male")
# Out:
# male

# %%
# Save model
from tensorflow.keras.models import load_model
model.save('gender_oke.h5')
model = load_model('gender_oke.h5')
